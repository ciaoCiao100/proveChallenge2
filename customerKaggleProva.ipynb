# %% [markdown]
# <a href="https://colab.research.google.com/github/ciaoCiao100/proveChallenge2/blob/master/customerKaggleProva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importo librerie

# %%
import pandas as pd
import functools
import numpy as np
import tensorflow as tf
from sklearn import tree
import matplotlib as plt
import nltk

import sklearn.metrics as metrics
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# %% [markdown]
# caricamento dastaset

# %%
# Path of the file to read
customer_file_path = "/content/drive/My Drive/WA_Fn-UseC_-Telco-Customer-Churn.train.csv"
df = pd.read_csv(customer_file_path)
df.head()
# Sostituisco ad ogni stringa vuola il valore 'NaN'
df.replace("", np.nan, inplace=True)
df.replace(" ", np.nan, inplace=True)
df.replace("?", np.nan, inplace=True)
df.head()
# Out:
#   Churn  customerID  ... MonthlyCharges  TotalCharges
# 0    No  4223-BKEOR  ...          64.85        1336.8
# 1    No  6035-RIIOM  ...          97.20       5129.45
# 2   Yes  3797-VTIDR  ...          23.45         23.45
# 3   Yes  2568-BRGYX  ...          70.20        237.95
# 4    No  2775-SEFEE  ...          61.90           NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# conversione da stringhe ad interi

# %%
#tutte le colonne che contengono stringhe devono essere trasformate in colonne che contengono interi 
for elemento in df:
 
  df[elemento] = pd.Categorical(df[elemento])
  df[elemento] = getattr(df, elemento).cat.codes
# mostro il dataset dopo l'operazione
df.head()
# Out:
#    Churn  customerID  gender  ...  PaymentMethod  MonthlyCharges  TotalCharges
# 0      0        2370       0  ...              3             586           491
# 1      0        3457       0  ...              0            1170          3510
# 2      1        2149       1  ...              2              59          1565
# 3      1        1426       1  ...              2             674          1626
# 4      0        1545       1  ...              0             546            -1
#
# [5 rows x 21 columns]

# %% [markdown]
# eliminazione colonne nulle

# %%
# Procediamo con l'eliminazione dei dati non validi (NaN)
df.dropna(inplace=True)
df.head()
# Out:
#    Churn  customerID  gender  ...  PaymentMethod  MonthlyCharges  TotalCharges
# 0      0        2370       0  ...              3             586           491
# 1      0        3457       0  ...              0            1170          3510
# 2      1        2149       1  ...              2              59          1565
# 3      1        1426       1  ...              2             674          1626
# 4      0        1545       1  ...              0             546            -1
#
# [5 rows x 21 columns]

# %% [markdown]
# eliminazione colonne inutili

# %%
df = df.drop(['customerID', 'gender', 'tenure','PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'], axis=1)
df.head()
# Out:
#    Churn  SeniorCitizen  Partner  ...  PaymentMethod  MonthlyCharges  TotalCharges
# 0      0              0        0  ...              3             586           491
# 1      0              0        0  ...              0            1170          3510
# 2      1              0        1  ...              2              59          1565
# 3      1              0        0  ...              2             674          1626
# 4      0              0        0  ...              0             546            -1
#
# [5 rows x 9 columns]

# %% [markdown]
# preparazione modello, addestramento validazione e test

# %%
#dataset diviso tra colonna churn (y) e le altre colonne (x) 
y = df.Churn
x = df
#dataset diviso per la parte di addestramento ,validazione e test
train_X, val_X, train_y, val_y = train_test_split(x, y, test_size=0.2)
train_X, test_X, train_y, test_y = train_test_split(train_X, train_y, test_size=0.1)

# Specify Model
model = DecisionTreeClassifier(random_state=1)
# Fit Model
model.fit(train_X, train_y)

train_acc = model.score(train_X, train_y)
prediction = model.predict(val_X)
validation_acc = accuracy_score(val_y, predict_dc.round())
print('Accuracy train: %s'  % train_acc)
print('Accuracy validation: %s'  % validation_acc)
pred_dc = model.predict(test_X)
test_acc = accuracy_score(test_y, pred_dc.round())
print('Accuracy test: %s'  % test_acc)
# Out:
# Accuracy train: 1.0
# Accuracy validation: 0.6042590949423248
# Accuracy test: 1.0
