# %% [markdown]
# <a href="https://colab.research.google.com/github/ciaoCiao100/proveChallenge2/blob/master/customerKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importo librerie

# %%
# !pip install --user requirements.txt
import pandas as pd
import functools
import numpy as np
import tensorflow as tf
from sklearn import tree
import matplotlib as plt
import nltk

import sklearn.metrics as metrics
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
 

# operazione che fa in modo che i numeri siano più leggibili
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# caricamento dastaset

# %%
# Path of the file to read
customer_file_path = "./WA_Fn-UseC_-Telco-Customer-Churn.train.csv"
df = pd.read_csv(customer_file_path)
df.head()
# Sostituisco ad ogni stringa vuota il valore 'NaN'
df.replace("", np.nan, inplace=True)
df.replace(" ", np.nan, inplace=True)
df.replace("?", np.nan, inplace=True)
df.head()
# Out:
#   Churn  customerID  ... MonthlyCharges  TotalCharges
# 0    No  4223-BKEOR  ...          64.85        1336.8
# 1    No  6035-RIIOM  ...          97.20       5129.45
# 2   Yes  3797-VTIDR  ...          23.45         23.45
# 3   Yes  2568-BRGYX  ...          70.20        237.95
# 4    No  2775-SEFEE  ...          61.90           NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# eliminazione righe Nan

# %%
# eliminazione dei dati non validi (NaN)
df.dropna(inplace=True)
df.head()
# Out:
#   Churn  customerID  ... MonthlyCharges  TotalCharges
# 0    No  4223-BKEOR  ...          64.85        1336.8
# 1    No  6035-RIIOM  ...          97.20       5129.45
# 2   Yes  3797-VTIDR  ...          23.45         23.45
# 3   Yes  2568-BRGYX  ...          70.20        237.95
# 5    No  4291-SHSBH  ...          69.55        521.35
#
# [5 rows x 21 columns]

# %% [markdown]
# conversione da stringhe a float

# %%
#tutte le colonne che contengono stringhe devono essere trasformate in colonne che contengono interi 
for elemento in df:
  if elemento=="MonthlyCharges" or elemento=="TotalCharges" or elemento=="tenure":
   df[elemento] = df[elemento].astype('float')
  else:
   df[elemento] = (pd.Categorical(df[elemento])).codes.astype('float')

# mostro il dataset dopo l'operazione
df.head()
# Out:
#    Churn  customerID  gender  ...  PaymentMethod  MonthlyCharges  TotalCharges
# 0    0.0      2364.0     0.0  ...            3.0           64.85       1336.80
# 1    0.0      3448.0     0.0  ...            0.0           97.20       5129.45
# 2    1.0      2143.0     1.0  ...            2.0           23.45         23.45
# 3    1.0      1424.0     1.0  ...            2.0           70.20        237.95
# 5    0.0      2394.0     1.0  ...            2.0           69.55        521.35
#
# [5 rows x 21 columns]

# %% [markdown]
# eliminazione colonne inutili

# %%
df = df.drop(['customerID', 'gender'], axis=1)
df.head()
# Out:
#    Churn  SeniorCitizen  Partner  ...  PaymentMethod  MonthlyCharges  TotalCharges
# 0    0.0            0.0      0.0  ...            3.0           64.85       1336.80
# 1    0.0            0.0      0.0  ...            0.0           97.20       5129.45
# 2    1.0            0.0      1.0  ...            2.0           23.45         23.45
# 3    1.0            0.0      0.0  ...            2.0           70.20        237.95
# 5    0.0            0.0      0.0  ...            2.0           69.55        521.35
#
# [5 rows x 19 columns]

# %% [markdown]
# preparazione modello

# %%
train, test = train_test_split(df)
features =['SeniorCitizen','Partner','Dependents','tenure','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','MonthlyCharges','TotalCharges']
X = train[features]
Y = train['Churn']
X_test = test[features]
Y_test =test['Churn']

# Specify Model : viene utilizzato RandomForestCLaasifier
#La foresta casuale, come suggerisce il nome, 
#è costituita da un gran numero di singoli alberi decisionali che operano come un insieme(differentemente per il DecisionTreeClassifier che opera su un albero di decisione).
#Ogni singolo albero nella foresta casuale genera una previsione di classe basandosi sui suoi attributi ed esprime un voto per quella classe
# e la classe con il maggior numero di voti diventa la previsione del nostro modello
#Mentre alcuni alberi potrebbero essere sbagliati, molti altri alberi avranno ragione, quindi come gruppo gli alberi sono in grado di muoversi nella direzione corretta. 
#Le previsioni (e quindi gli errori) fatte dai singoli alberi devono avere basse correlazioni tra loro.
model = RandomForestClassifier(random_state=1)
# Fit Model
model.fit(X, Y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %% [markdown]
# train

# %%
train_predictions = model.predict(X)
train_acc = metrics.accuracy_score(Y,train_predictions)
print('Accuracy train: %s'  % train_acc)
# Out:
# Accuracy train: 0.9983404457088667

# %% [markdown]
# test

# %%
test_predictions = model.predict(X_test)
test_acc=metrics.accuracy_score(Y_test,test_predictions)
print('Accuracy test: %s'  % test_acc)
# Out:
# Accuracy test: 0.7972972972972973
