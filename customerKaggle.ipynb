# %% [markdown]
# <a href="https://colab.research.google.com/github/ciaoCiao100/proveChallenge2/blob/master/customerKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importo librerie

# %%
import pandas as pd
import functools
import numpy as np
import tensorflow as tf
from sklearn import tree
import matplotlib as plt
import nltk

import sklearn.metrics as metrics
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split


# operazione che fa in modo che i numeri siano più leggibili
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# caricamento dastaset

# %%
# Path of the file to read
customer_file_path = "/content/drive/My Drive/WA_Fn-UseC_-Telco-Customer-Churn.train.csv"
df = pd.read_csv(customer_file_path)
df.head()
# Sostituisco ad ogni stringa vuota il valore 'NaN'
#df.replace("", np.nan, inplace=True)
#df.replace(" ", np.nan, inplace=True)
#df.replace("?", np.nan, inplace=True)
#df.head()
# Out:
#   Churn  customerID  ... MonthlyCharges  TotalCharges
# 0    No  4223-BKEOR  ...          64.85        1336.8
# 1    No  6035-RIIOM  ...          97.20       5129.45
# 2   Yes  3797-VTIDR  ...          23.45         23.45
# 3   Yes  2568-BRGYX  ...          70.20        237.95
# 4    No  2775-SEFEE  ...          61.90
#
# [5 rows x 21 columns]

# %% [markdown]
# eliminazione elementi nulli

# %%
# Procediamo con l'eliminazione dei dati non validi (NaN)
#df.dropna(inplace=True)
#df.head()
# Out:
#    Churn  customerID  ...  MonthlyCharges  TotalCharges
# 0      0        2364  ...             585           491
# 1      0        3448  ...            1169          3510
# 2      1        2143  ...              59          1565
# 3      1        1424  ...             673          1626
# 5      0        2394  ...             660          3548
#
# [5 rows x 19 columns]

# %% [markdown]
# conversione da stringhe ad interi

# %%
#tutte le colonne che contengono stringhe devono essere trasformate in colonne che contengono interi 
for elemento in df:
 
  df[elemento] = pd.Categorical(df[elemento])
  df[elemento] = getattr(df, elemento).cat.codes
  if elemento=="MonthlyCharges" or elemento=="TotalCharges" or elemento=="tenure":
   df[elemento] = df[elemento].astype('float')
  else:
   df[elemento] = (pd.Categorical(df[elemento])).codes.astype('float')

# mostro il dataset dopo l'operazione
df.head()
# Out:
#    Churn  customerID  gender  ...  PaymentMethod  MonthlyCharges  TotalCharges
# 0    0.0      2370.0     0.0  ...            3.0           586.0         492.0
# 1    0.0      3457.0     0.0  ...            0.0          1170.0        3511.0
# 2    1.0      2149.0     1.0  ...            2.0            59.0        1566.0
# 3    1.0      1426.0     1.0  ...            2.0           674.0        1627.0
# 4    0.0      1545.0     1.0  ...            0.0           546.0           0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# eliminazione colonne nulle

# %% [markdown]
# eliminazione colonne inutili

# %%
df = df.drop(['customerID', 'gender','Partner'], axis=1)
df.head()
# Out:
#    Churn  SeniorCitizen  ...  MonthlyCharges  TotalCharges
# 0    0.0            0.0  ...           586.0         492.0
# 1    0.0            0.0  ...          1170.0        3511.0
# 2    1.0            0.0  ...            59.0        1566.0
# 3    1.0            0.0  ...           674.0        1627.0
# 4    0.0            0.0  ...           546.0           0.0
#
# [5 rows x 18 columns]

# %% [markdown]
# preparazione modello

# %%
train, test = train_test_split(df)
features =['SeniorCitizen','Dependents','tenure','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','MonthlyCharges','TotalCharges']
X = train[features]
Y = train['Churn']
X_test = test[features]
Y_test =test['Churn']

# Specify Model
model = DecisionTreeClassifier(random_state=1)
# Fit Model
model.fit(X, Y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1, splitter='best')

# %% [markdown]
# train

# %%
train_predictions = model.predict(X)
train_acc = metrics.accuracy_score(Y,train_predictions)
print('Accuracy train: %s'  % train_acc)
# Out:
# Accuracy train: 0.9983431952662722

# %% [markdown]
# test

# %%
test_predictions = model.predict(X_test)
test_acc=metrics.accuracy_score(Y_test,test_predictions)
print('Accuracy test: %s'  % test_acc)
# Out:
# Accuracy test: 0.7324343506032647
